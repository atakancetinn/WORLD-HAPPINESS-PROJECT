# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
df = pd.read_csv('2015.csv')
df1 = pd.read_csv('2016.csv')
df2 = pd.read_csv('2017.csv')
df3 = pd.read_csv('2018.csv')
df4 = pd.read_csv('2019.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.columns=df.columns.str.replace(' ','_')
df1.columns=df1.columns.str.replace(' ','_')
df3.columns=df3.columns.str.replace(' ','_')
df4.columns=df4.columns.str.replace(' ','_')

# %%
## 10 Happiest Countries Between 2015-2019

# %%
sns.barplot(x = df["Happiness_Score"][:10], y = df["Country"][:10])
# Out:
# <Axes: xlabel='Happiness_Score', ylabel='Country'>

# %%
sns.barplot(x = df1["Happiness_Score"][:10], y = df1["Country"][:10])
# Out:
# <Axes: xlabel='Happiness_Score', ylabel='Country'>

# %%
sns.barplot(x = df2["Happiness.Score"][:10], y = df2["Country"][:10])
# Out:
# <Axes: xlabel='Happiness.Score', ylabel='Country'>

# %%
sns.barplot(x = df3["Score"][:10], y = df3["Country_or_region"][:10])
# Out:
# <Axes: xlabel='Score', ylabel='Country_or_region'>

# %%
sns.barplot(x = df4["Score"][:10], y = df4["Country_or_region"][:10])
# Out:
# <Axes: xlabel='Score', ylabel='Country_or_region'>

# %%
df3
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df4
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
##Top 10 Countries According to Factors Affecting Overall Happiness in 2019

# %%
plt.figure(figsize = (15,5),facecolor = 'white' )
data = df4.sort_values(by = ["GDP_per_capita"],ascending = False)
sns.barplot(data.head(10), x="Country_or_region", y="GDP_per_capita")
# Out:
# <Axes: xlabel='Country_or_region', ylabel='GDP_per_capita'>

# %%
plt.figure(figsize = (15,5),facecolor = 'white' )
data1 = df4.sort_values(by = ["Social_support"],ascending = False)
sns.barplot(data1.head(10), x="Country_or_region", y="Social_support")
# Out:
# <Axes: xlabel='Country_or_region', ylabel='Social_support'>

# %%
plt.figure(figsize = (15,5),facecolor = 'white' )
data2 = df4.sort_values(by = ["Healthy_life_expectancy"],ascending = False)
sns.barplot(data2.head(10), x="Country_or_region", y="Healthy_life_expectancy")
# Out:
# <Axes: xlabel='Country_or_region', ylabel='Healthy_life_expectancy'>

# %%
plt.figure(figsize = (15,5),facecolor = 'white' )
data3 = df4.sort_values(by = ["Freedom_to_make_life_choices"],ascending = False)
sns.barplot(data3.head(10), x="Country_or_region", y="Freedom_to_make_life_choices")
# Out:
# <Axes: xlabel='Country_or_region', ylabel='Freedom_to_make_life_choices'>

# %%
plt.figure(figsize = (15,5),facecolor = 'white' )
data4 = df4.sort_values(by = ["Generosity"],ascending = False)
sns.barplot(data4.head(10), x="Country_or_region", y="Generosity")
# Out:
# <Axes: xlabel='Country_or_region', ylabel='Generosity'>

# %%
plt.figure(figsize = (15,5),facecolor = 'white' )
data5 = df4.sort_values(by = ["Perceptions_of_corruption"],ascending = False)
sns.barplot(data5.head(10), x="Country_or_region", y="Perceptions_of_corruption")
# Out:
# <Axes: xlabel='Country_or_region', ylabel='Perceptions_of_corruption'>

# %%
## Changes of Happiness Scores Between 2015-2016 and 2016-2017

# %%
comparation = pd.DataFrame()

# %%
comparation["2015"] = df["Happiness_Score"]
comparation["2016"] = df1["Happiness_Score"]
comparation["2017"] = df2["Happiness.Score"]
comparation["2015"] = df["Country"]
comparation["2016"] = df1["Country"]
comparation["2017"] = df2["Country"]

# %%
comparation.head(10)
# Out:
#           2015         2016         2017
# 0  Switzerland      Denmark       Norway
# 1      Iceland  Switzerland      Denmark
# 2      Denmark      Iceland      Iceland
# 3       Norway       Norway  Switzerland
# 4       Canada      Finland      Finland
# 5      Finland       Canada  Netherlands
# 6  Netherlands  Netherlands       Canada
# 7       Sweden  New Zealand  New Zealand
# 8  New Zealand    Australia       Sweden
# 9    Australia       Sweden    Australia

# %%
## Has any Country Experienced a Significant Increase or Decrease in Happiness?

# %%
comparation1 = pd.DataFrame()

# %%
comparation1["2015"] = df["Happiness_Score"]
comparation1["2016"] = df1["Happiness_Score"]
comparation1["2017"] = df2["Happiness.Score"]
comparation1["2015"] = df["Country"]
comparation1["2016"] = df1["Country"]
comparation1["2017"] = df2["Country"]
comparation1["Change2015-2016"] = df["Happiness_Score"] - df1["Happiness_Score"]
comparation1["Change2016-2017"] = df1["Happiness_Score"] - df2["Happiness.Score"]

# %%
comparation1
# Out:
#             2015         2016                      2017  Change2015-2016  \
# 0    Switzerland      Denmark                    Norway            0.061
# 1        Iceland  Switzerland                   Denmark            0.052
# 2        Denmark      Iceland                   Iceland            0.026
# 3         Norway       Norway               Switzerland            0.024
# 4         Canada      Finland                   Finland            0.014
# ..           ...          ...                       ...              ...
# 153       Rwanda  Afghanistan                   Burundi            0.105
# 154        Benin         Togo  Central African Republic            0.037
# 155        Syria        Syria                       NaN           -0.063
# 156      Burundi      Burundi                       NaN            0.000
# 157         Togo          NaN                       NaN              NaN
#
#      Change2016-2017
# 0             -0.011
# 1             -0.013
# 2             -0.003
# ...

# %%
comparation1["Change2015-2016"].max()
# Out:
# 0.18299999999999983

# %%
comparation1[comparation1["Change2015-2016"] > 0.182]  ## Most rank climbed country between 2015-2016
# Out:
#              2015     2016        2017  Change2015-2016  Change2016-2017
# 122  Sierra Leone  Ukraine  Mauritania            0.183            0.032

# %%
comparation1["Change2015-2016"].min()
# Out:
# -0.1620000000000008

# %%
comparation1[comparation1["Change2015-2016"] < -0.162]  ##Most rank down country between 2015-2016
# Out:
#        2015       2016     2017  Change2015-2016  Change2016-2017
# 94  Albania  Macedonia  Nigeria           -0.162            0.047

# %%
comparation1["Change2016-2017"].max()
# Out:
# 0.60999992179871

# %%
comparation1[comparation1["Change2016-2017"] > 0.60]  ## Most rank climbed country between 2016-2017
# Out:
#       2015  2016                      2017  Change2015-2016  Change2016-2017
# 154  Benin  Togo  Central African Republic            0.037             0.61

# %%
comparation1["Change2016-2017"].min()
# Out:
# -0.08200021743773966

# %%
comparation1[comparation1["Change2016-2017"] < -0.082]   ##Most rank down country between 2016-2017
# Out:
#       2015       2016  2017  Change2015-2016  Change2016-2017
# 116  India  Sri Lanka  Iraq             0.15           -0.082
